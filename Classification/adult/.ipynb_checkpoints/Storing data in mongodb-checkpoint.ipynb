# %% [markdown]
# # Connecting to MongoDB

# %%
import pymongo


client = pymongo.MongoClient("mongodb+srv://akayyy:password4atharv@datascience-cluster.0t8k7za.mongodb.net/?retryWrites=true&w=majority")
print(client)
# Out:
# MongoClient(host=['ac-az3wl0c-shard-00-01.0t8k7za.mongodb.net:27017', 'ac-az3wl0c-shard-00-00.0t8k7za.mongodb.net:27017', 'ac-az3wl0c-shard-00-02.0t8k7za.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-aj9xun-shard-0', tls=True)

# %%
db = client['adult_census_data']
col = db['encoded_data']

# %% [markdown]
# # Importing CSV to be uploaded to MongoDB

# %%
import pandas as pd
data = pd.read_csv('census_data_encoded.csv')
data.drop(columns='Unnamed: 0',axis=1,inplace=True)
data.head()
# Out:
#    fnlwgt  edu-num  capital-gain  capital-loss  hrs-per-week  earnings  age  \
# 0   77516       13          2174             0            40         0   39
# 1   83311       13             0             0            13         0   50
# 2  215646        9             0             0            40         0   38
# 3  234721        7             0             0            40         0   53
# 4  338409       13             0             0            40         0   28
#
#    workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  ...  \
# 0                       0                     0                        0  ...
# 1                       0                     0                        0  ...
# 2                       0                     0                        0  ...
# 3                       0                     0                        0  ...
# 4                       0                     0                        0  ...
#
# ...

# %%
col.insert_many(data.to_dict('records'))

# %%
df_mongodb = pd.DataFrame(list(col.find()))

# %%
df_mongodb.drop('_id', axis=1, inplace=True)
df_mongodb.head()
# Out:
#    fnlwgt  edu-num  capital-gain  capital-loss  hrs-per-week  earnings  age  \
# 0   77516       13          2174             0            40         0   39
# 1   83311       13             0             0            13         0   50
# 2  215646        9             0             0            40         0   38
# 3  234721        7             0             0            40         0   53
# 4  338409       13             0             0            40         0   28
#
#    workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  ...  \
# 0                       0                     0                        0  ...
# 1                       0                     0                        0  ...
# 2                       0                     0                        0  ...
# 3                       0                     0                        0  ...
# 4                       0                     0                        0  ...
#
# ...

# %% [markdown]
# **the export of csv file to mongodb verified**
